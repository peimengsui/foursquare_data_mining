# %%
import csv
l=[]
with open('nytownnames.csv') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    for row in readCSV:
        l.append(row[0])

# %%
names = [x.strip(' ') for x in l]

# %%
names
# Out:
# ['Adams',
#  'Addison',
#  'Afton',
#  'Airmont',
#  'Akron',
#  'Alabama',
#  'Albany',
#  'Albion',
#  'Alden',
#  'Alexander',
#  'Alexandria',
#  'Alexandria Bay',
#  'Alfred',
#  'Allegany',
#  'Allen',
#  'Alma',
#  'Almond',
#  'Altamont',
#  'Altamont',
#  '(changed to Tupper Lake 2004)',
#  'Altmar',
#  'Altona',
#  'Amboy',
#  'Amchir',
#  'Amenia',
#  'Ames',
#  'Amherst',
#  'Amity',
#  'Amityville',
#  'Amsterdam',
#  'Ancram',
#  'Andes',
#  'Andover',
#  'Angelica',
#  'Angola',
#  'Annsville',
#  'Antwerp',
#  'Arcade',
#  'Arcadia',
#  'Ardsley',
#  'Argyle',
#  'Arietta',
#  'Arkport',
#  'Arkwright',
#  'Asharoken',
#  'Ashford',
#  'Ashland',
#  'Athens',
#  'Atlantic Beach',
#  'Attica',
#  'Auburn',
#  'Augusta',
#  'Aurelius',
#  'Aurora',
#  'Ausable',
#  'Austerlitz',
#  'Ava',
#  'Avoca',
#  'Avon',
#  'Babylon',
#  'Bainbridge',
#  'Baldwin',
#  'Baldwinsville',
#  'Ballston',
#  'Ballston Spa',
#  'Bangor',
#  'Barker',
#  'Barneveld',
#  'Barre',
# ...

# %%
import pandas as pd
cols = ["Name","Cat","County"]
table = pd.read_table("nytownlist.txt",names=cols)

# %%
names = table["Name"]

# %%
type(names)
# Out:
# pandas.core.series.Series

# %%
names=names.drop_duplicates()

# %%
names.to_csv("nytownnames.csv",index=False)

# %%
se = pd.read_csv('nytownnames.csv',names = ["name"])

# %%
se = se.drop_duplicates()

# %%
l=[]
for ind,val in se.iteritems():
    l.append(val)
